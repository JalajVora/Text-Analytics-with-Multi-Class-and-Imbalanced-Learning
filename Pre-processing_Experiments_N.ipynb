# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# define data locations

data_dir = 'Gutenberg_English_Fiction_1k/'
target_file = 'master996.csv'
corpus_dir = 'Gutenberg_19th_century_English_Fiction/'

# %%
# import target

data = pd.read_csv(data_dir + target_file, sep=';', engine='python')
data.loc[:]['book_id'] = data['book_id'].apply(lambda book_id: book_id[:-5]) # remove '.epub' ending
data.set_index('book_id', inplace=True)
data
# Out:
#                                                                   Book_Name  \
# book_id
# pg10067                   The Mystery of the Boule Cabinet: A Detective ...
# pg1032                                                            The Pupil
# pg10379                                                      At Love's Cost
# pg10473                                              The Heart of the Range
# pg10812                                         The Worshipper of the Image
# pg10826                   The Book-Bills of Narcissus - An Account Rende...
# pg10943                                                      Elusive Isabel
# pg11004                                              Joe Burke's Last Stand
# pg11005                                                                 O+F
# pg11259                                              Polly and the Princess
# pg11280                      Maggie Miller: The Story of Old Hagar's Secret
# pg11520                                                   The Obstacle Race
# pg11581                                             From out the Vasty Deep
# pg11655                                    Fate Knocks at the Door: A Novel
# pg11674                                        The Torrent (Entre Naranjos)
# pg1190                                                     The Jolly Corner
# pg1193                                                       The Coxon Fund
# pg11931                                       The Mystery of Monastery Farm
# pg11970                                                   Wife in Name Only
# pg12102                                         Darrel of the Blessed Isles
# pg1218                                        The Adventures of Jimmie Dale
# pg12181                                        The Story of Bessie Costrell
# pg12303                                           Fated to Be Free: A Novel
# pg12304                                                      Nancy: A Novel
# pg12360                                                The Top of the World
# pg12450                                                      The Reason Why
# pg12453                                            Miriam Monfort - A Novel
# pg12470                                                   A Perilous Secret
# pg12520                                             Deadham Hard: A Romance
# pg1253                                                        A Simple Soul
# ...                                                                     ...
# pg1400DickensGreatExp                                    Great Expectations
# pg141JaneAusMansPark                                         Mansfield Park
# pg158JaneAustenEmma                                                    Emma
# pg161SJaneAusSensSensi                                Sense and Sensibility
# pg19337DickensChristCarl                                  A Christmas Carol
# pg2097DoyleSignFour                                        The Sign of Four
# pg2147EdgarPoe1                              The Works of Edgar Allan Poe I
# pg2148EdgarPoe2                             The Works of Edgar Allan Poe II
# pg2149EdgarPoe3                            The Works of Edgar Allan Poe III
# pg2150EdgarPoe4                             The Works of Edgar Allan Poe IV
# pg21816HermanConfidence                                  The Confidence-Man
# pg2684Galsw4                                                     Five Tales
# pg2701HermanMobyDick                                              Moby Dick
# pg2852DoyleHound                              The Hound of the Baskervilles
# pg29042CarolTangTale                                         A Tangled Tale
# pg2911Galsw2                                                        Justice
# pg2919Galsw5                                                 The Little Man
# pg34970HermanPierre                               Pierre or The Ambiguities
# pg4045HermanOmmo                          Omoo Adventures in the South Seas
# pg4397Galsw1                                               The Forsyte Saga
# pg4763CarolLogik                                          The Game of Logic
# pg4765Galsw3                                                      Loyalties
# pg537DoyleTerrorTales                           Tales of Terror and Mystery
# pg620CarolBruno                                            Sylvie and Bruno
# pg730DickensOliverTw                                           Oliver Twist
# pg766DickensDavidCopfld                                   David Copperfield
# pg786DickensHardTimes                                            Hard Times
# pg834DoyleMemoirsSherlk                           Memoirs of Shelock Holmes
# pg863Agatha1                                The Mysterious Affair at Styles
# pg98DickensTaleCities                                  A Tale of Two Cities
#
#                                     guten_genre               Author_Name
# book_id
# pg10067                   Detective and Mystery  Stevenson| Burton Egbert
# pg1032                                 Literary              James| Henry
# pg10379                                Literary          Garvice| Charles
# pg10473                         Western Stories  White| William Patterson
# pg10812                                Literary     Gallienne| Richard Le
# pg10826                                Literary     Gallienne| Richard Le
# pg10943                   Detective and Mystery         Futrelle| Jacques
# pg11004                                Literary    Wetterau| John Moncure
# pg11005                                Literary    Wetterau| John Moncure
# pg11259                                Literary             Dowd| Emma C.
# pg11280                                Literary         Holmes| Mary Jane
# pg11520                                Literary            Dell| Ethel M.
# pg11581                                Literary     Lowndes| Marie Belloc
# pg11655                                Literary   Comfort| Will Levington
# pg11674                                Literary      Ibez| Vicente Blasco
# pg1190                         Ghost and Horror              James| Henry
# pg1193                                 Literary              James| Henry
# pg11931                                Literary             Naylor| H. R.
# pg11970                                Literary       Brame| Charlotte M.
# pg12102                                Literary         Bacheller| Irving
# pg1218                    Detective and Mystery         Packard| Frank L.
# pg12181                                Literary        Ward| Mrs. Humphry
# pg12303                                Literary             Ingelow| Jean
# pg12304                                Literary          Broughton| Rhoda
# pg12360                                Literary            Dell| Ethel M.
# pg12450                                Literary              Glyn| Elinor
# pg12453                                Literary    Warfield| Catherine A.
# pg12470                                Literary            Reade| Charles
# pg12520                                Literary              Malet| Lucas
# pg1253                                 Literary         Flaubert| Gustave
# ...                                         ...                       ...
# pg1400DickensGreatExp                  Literary          Dickens| Charles
# pg141JaneAusMansPark                   Literary              Austen| Jane
# pg158JaneAustenEmma                    Literary              Austen| Jane
# pg161SJaneAusSensSensi                 Literary              Austen| Jane
# pg19337DickensChristCarl      Christmas Stories          Dickens| Charles
# pg2097DoyleSignFour       Detective and Mystery             Connan| Doyle
# pg2147EdgarPoe1           Detective and Mystery          Poe| Edgar Allan
# pg2148EdgarPoe2           Detective and Mystery          Poe| Edgar Allan
# pg2149EdgarPoe3           Detective and Mystery          Poe| Edgar Allan
# pg2150EdgarPoe4           Detective and Mystery          Poe| Edgar Allan
# pg21816HermanConfidence                Literary          Melville| Herman
# pg2684Galsw4                           Literary          Galsworthy| John
# pg2701HermanMobyDick          Sea and Adventure          Melville| Herman
# pg2852DoyleHound          Detective and Mystery             Connan| Doyle
# pg29042CarolTangTale                   Literary            Carroll| Lewis
# pg2911Galsw2                           Literary          Galsworthy| John
# pg2919Galsw5                           Literary          Galsworthy| John
# pg34970HermanPierre                    Literary          Melville| Herman
# pg4045HermanOmmo              Sea and Adventure          Melville| Herman
# pg4397Galsw1                           Literary          Galsworthy| John
# pg4763CarolLogik                       Literary            Carroll| Lewis
# pg4765Galsw3                           Literary          Galsworthy| John
# pg537DoyleTerrorTales     Detective and Mystery             Connan| Doyle
# pg620CarolBruno                        Literary            Carroll| Lewis
# pg730DickensOliverTw                   Literary          Dickens| Charles
# pg766DickensDavidCopfld                Literary          Dickens| Charles
# pg786DickensHardTimes                  Literary          Dickens| Charles
# pg834DoyleMemoirsSherlk   Detective and Mystery             Connan| Doyle
# pg863Agatha1              Detective and Mystery          Christie| Agatha
# pg98DickensTaleCities                  Literary          Dickens| Charles
#
# [996 rows x 3 columns]

# %%
# import corpus

def get_book_content(book_id):      
    filename = data_dir + corpus_dir + book_id + '-content.html'
    
    with open(filename, encoding='utf-8') as file:        
        try:
            content = file.read()
            
        except UnicodeDecodeError:
            print('UnicodeDecodeError trying to read {}. Returning None.'.format(book_id))
            return None
        
        content = content.replace('<p>','')   
        
    return content

data['content'] = [get_book_content(book_id) for book_id in data.index]
data
# Out:
#                                                                   Book_Name  \
# book_id
# pg10067                   The Mystery of the Boule Cabinet: A Detective ...
# pg1032                                                            The Pupil
# pg10379                                                      At Love's Cost
# pg10473                                              The Heart of the Range
# pg10812                                         The Worshipper of the Image
# pg10826                   The Book-Bills of Narcissus - An Account Rende...
# pg10943                                                      Elusive Isabel
# pg11004                                              Joe Burke's Last Stand
# pg11005                                                                 O+F
# pg11259                                              Polly and the Princess
# pg11280                      Maggie Miller: The Story of Old Hagar's Secret
# pg11520                                                   The Obstacle Race
# pg11581                                             From out the Vasty Deep
# pg11655                                    Fate Knocks at the Door: A Novel
# pg11674                                        The Torrent (Entre Naranjos)
# pg1190                                                     The Jolly Corner
# pg1193                                                       The Coxon Fund
# pg11931                                       The Mystery of Monastery Farm
# pg11970                                                   Wife in Name Only
# pg12102                                         Darrel of the Blessed Isles
# pg1218                                        The Adventures of Jimmie Dale
# pg12181                                        The Story of Bessie Costrell
# pg12303                                           Fated to Be Free: A Novel
# pg12304                                                      Nancy: A Novel
# pg12360                                                The Top of the World
# pg12450                                                      The Reason Why
# pg12453                                            Miriam Monfort - A Novel
# pg12470                                                   A Perilous Secret
# pg12520                                             Deadham Hard: A Romance
# pg1253                                                        A Simple Soul
# ...                                                                     ...
# pg1400DickensGreatExp                                    Great Expectations
# pg141JaneAusMansPark                                         Mansfield Park
# pg158JaneAustenEmma                                                    Emma
# pg161SJaneAusSensSensi                                Sense and Sensibility
# pg19337DickensChristCarl                                  A Christmas Carol
# pg2097DoyleSignFour                                        The Sign of Four
# pg2147EdgarPoe1                              The Works of Edgar Allan Poe I
# pg2148EdgarPoe2                             The Works of Edgar Allan Poe II
# pg2149EdgarPoe3                            The Works of Edgar Allan Poe III
# pg2150EdgarPoe4                             The Works of Edgar Allan Poe IV
# pg21816HermanConfidence                                  The Confidence-Man
# pg2684Galsw4                                                     Five Tales
# pg2701HermanMobyDick                                              Moby Dick
# pg2852DoyleHound                              The Hound of the Baskervilles
# pg29042CarolTangTale                                         A Tangled Tale
# pg2911Galsw2                                                        Justice
# pg2919Galsw5                                                 The Little Man
# pg34970HermanPierre                               Pierre or The Ambiguities
# pg4045HermanOmmo                          Omoo Adventures in the South Seas
# pg4397Galsw1                                               The Forsyte Saga
# pg4763CarolLogik                                          The Game of Logic
# pg4765Galsw3                                                      Loyalties
# pg537DoyleTerrorTales                           Tales of Terror and Mystery
# pg620CarolBruno                                            Sylvie and Bruno
# pg730DickensOliverTw                                           Oliver Twist
# pg766DickensDavidCopfld                                   David Copperfield
# pg786DickensHardTimes                                            Hard Times
# pg834DoyleMemoirsSherlk                           Memoirs of Shelock Holmes
# pg863Agatha1                                The Mysterious Affair at Styles
# pg98DickensTaleCities                                  A Tale of Two Cities
#
#                                     guten_genre               Author_Name  \
# book_id
# pg10067                   Detective and Mystery  Stevenson| Burton Egbert
# pg1032                                 Literary              James| Henry
# pg10379                                Literary          Garvice| Charles
# pg10473                         Western Stories  White| William Patterson
# pg10812                                Literary     Gallienne| Richard Le
# pg10826                                Literary     Gallienne| Richard Le
# pg10943                   Detective and Mystery         Futrelle| Jacques
# pg11004                                Literary    Wetterau| John Moncure
# pg11005                                Literary    Wetterau| John Moncure
# pg11259                                Literary             Dowd| Emma C.
# pg11280                                Literary         Holmes| Mary Jane
# pg11520                                Literary            Dell| Ethel M.
# pg11581                                Literary     Lowndes| Marie Belloc
# pg11655                                Literary   Comfort| Will Levington
# pg11674                                Literary      Ibez| Vicente Blasco
# pg1190                         Ghost and Horror              James| Henry
# pg1193                                 Literary              James| Henry
# pg11931                                Literary             Naylor| H. R.
# pg11970                                Literary       Brame| Charlotte M.
# pg12102                                Literary         Bacheller| Irving
# pg1218                    Detective and Mystery         Packard| Frank L.
# pg12181                                Literary        Ward| Mrs. Humphry
# pg12303                                Literary             Ingelow| Jean
# pg12304                                Literary          Broughton| Rhoda
# pg12360                                Literary            Dell| Ethel M.
# pg12450                                Literary              Glyn| Elinor
# pg12453                                Literary    Warfield| Catherine A.
# pg12470                                Literary            Reade| Charles
# pg12520                                Literary              Malet| Lucas
# pg1253                                 Literary         Flaubert| Gustave
# ...                                         ...                       ...
# pg1400DickensGreatExp                  Literary          Dickens| Charles
# pg141JaneAusMansPark                   Literary              Austen| Jane
# pg158JaneAustenEmma                    Literary              Austen| Jane
# pg161SJaneAusSensSensi                 Literary              Austen| Jane
# pg19337DickensChristCarl      Christmas Stories          Dickens| Charles
# pg2097DoyleSignFour       Detective and Mystery             Connan| Doyle
# pg2147EdgarPoe1           Detective and Mystery          Poe| Edgar Allan
# pg2148EdgarPoe2           Detective and Mystery          Poe| Edgar Allan
# pg2149EdgarPoe3           Detective and Mystery          Poe| Edgar Allan
# pg2150EdgarPoe4           Detective and Mystery          Poe| Edgar Allan
# pg21816HermanConfidence                Literary          Melville| Herman
# pg2684Galsw4                           Literary          Galsworthy| John
# pg2701HermanMobyDick          Sea and Adventure          Melville| Herman
# pg2852DoyleHound          Detective and Mystery             Connan| Doyle
# pg29042CarolTangTale                   Literary            Carroll| Lewis
# pg2911Galsw2                           Literary          Galsworthy| John
# pg2919Galsw5                           Literary          Galsworthy| John
# pg34970HermanPierre                    Literary          Melville| Herman
# pg4045HermanOmmo              Sea and Adventure          Melville| Herman
# pg4397Galsw1                           Literary          Galsworthy| John
# pg4763CarolLogik                       Literary            Carroll| Lewis
# pg4765Galsw3                           Literary          Galsworthy| John
# pg537DoyleTerrorTales     Detective and Mystery             Connan| Doyle
# pg620CarolBruno                        Literary            Carroll| Lewis
# pg730DickensOliverTw                   Literary          Dickens| Charles
# pg766DickensDavidCopfld                Literary          Dickens| Charles
# pg786DickensHardTimes                  Literary          Dickens| Charles
# pg834DoyleMemoirsSherlk   Detective and Mystery             Connan| Doyle
# pg863Agatha1              Detective and Mystery          Christie| Agatha
# pg98DickensTaleCities                  Literary          Dickens| Charles
#
#                                                                     content
# book_id
# pg10067                   A Detective Story\nA.B.M. Fellow-Sherlockian\n...
# pg1032                    This edition first published 1916\nThe text fo...
# pg10379                   "Until this moment I have never fully realised...
# pg10473                   "The Rider of Golden Bar," "Hidden Trails," "L...
# pg10812                   The Worshipper of the Image\nEvening was in th...
# pg10826                   December 6th, 1894.\nNOTE. - This third editio...
# pg10943                   All the world rubs elbows in Washington. Outwa...
# pg11004                   Joe Burke's Last Stand\nEvery Story Is A Love ...
# pg11005                   John Moncure Wetterau\nLibrary of Congress Num...
# pg11259                   The June Holiday Home was one of those sumptuo...
# pg11280                   "Lead us not into temptation."\n'Mid the New E...
# pg11520                   The Obstacle Race\n"So run, that ye may obtain...
# pg11581                   Glendower: "I can call spirits from the vasty ...
# pg11655                   Fate Knocks At The Door\nA Novel\nWill Levingt...
# pg11674                   "Your friends are waiting for you at the Club....
# pg1190                    "Every one asks me what I 'think' of everythin...
# pg1193                    Decorative graphic\nThis edition first publish...
# pg11931                   The Mystery of Monastery Farm\nOn the eleventh...
# pg11970                   Dora Thorne From Gloom to Sunlight Her Martyrd...
# pg12102                   EBEN HOLDEN D'RI AND I CANDLE-LIGHT, Etc.\nTo ...
# pg1218                    Among New York's fashionable and ultra-exclusi...
# pg12181                   It was an August evening, still and cloudy aft...
# pg12303                   A Novel\nWhen authors attempt to explain such ...
# pg12304                   "Put into a small preserving pan three ounces ...
# pg12360                   Ethel M. Dell\n"The years shall not outgo my t...
# pg12450                   People often wondered what nation the great fi...
# pg12453                   BROWNING, "The Ring and the Book"\nThis book i...
# pg12470                   Two worn travellers, a young man and a fair gi...
# pg12520                   A Romance\n"Youth has no boundaries, age has t...
# pg1253                    For half a century the housewives of Pont-l'Ev...
# ...                                                                     ...
# pg1400DickensGreatExp     My father's family name being Pirrip, and my C...
# pg141JaneAusMansPark      About thirty years ago Miss Maria Ward, of Hun...
# pg158JaneAustenEmma       Emma Woodhouse, handsome, clever, and rich, wi...
# pg161SJaneAusSensSensi    The family of Dashwood had long been settled i...
# pg19337DickensChristCarl  The combined qualities of the realist and the ...
# pg2097DoyleSignFour       Sherlock Holmes took his bottle from the corne...
# pg2147EdgarPoe1           THIS stanza from "The Raven" was recommended b...
# pg2148EdgarPoe2           At Paris, just after dark one gusty evening in...
# pg2149EdgarPoe3           UPON my return to the United States a few mont...
# pg2150EdgarPoe4           EVERYBODY knows, in a general way, that the fi...
# pg21816HermanConfidence   At sunrise on a first of April, there appeared...
# pg2684Galsw4              It was a dark room at that hour of six in the ...
# pg2701HermanMobyDick      The pale Usher - threadbare in coat, heart, bo...
# pg2852DoyleHound          Mr. Sherlock Holmes, who was usually very late...
# pg29042CarolTangTale      Minor punctuation errors have been changed wit...
# pg2911Galsw2              The scene is the managing clerk's room, at the...
# pg2919Galsw5              Afternoon, on the departure platform of an Aus...
# pg34970HermanPierre       IN old times authors were proud of the privile...
# pg4045HermanOmmo          IT WAS the middle of a bright tropical afterno...
# pg4397Galsw1              "The Forsyte Saga" was the title originally de...
# pg4763CarolLogik          To my Child-friend.\nI charm in vain; for neve...
# pg4765Galsw3              The dressing-room of CHARLES WINSOR, owner of ...
# pg537DoyleTerrorTales     The idea that the extraordinary narrative whic...
# pg620CarolBruno           - and then all the people cheered again, and o...
# pg730DickensOliverTw      Among other public buildings in a certain town...
# pg766DickensDavidCopfld   I do not find it easy to get sufficiently far ...
# pg786DickensHardTimes     The One Thing Needful\nMurdering the Innocents...
# pg834DoyleMemoirsSherlk   "I am afraid, Watson, that I shall have to go,...
# pg863Agatha1              The intense interest aroused in the public by ...
# pg98DickensTaleCities     !!!!  Book the First - Recalled to Life I.   T...
#
# [996 rows x 4 columns]

# %%
#to faster debug, i use a smaller subset of the texts right now:
data_content = data['content'][:1]

# %%
import maPrepro
data_content_filtered = maPrepro.prepare_texts(data_content, use_stemming=True)
data_content_filtered
# Out:
# Text Count:  1  Progress:
# 0
# [nltk_data] Downloading package stopwords to /Users/nani/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/nani/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/nani/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ["A Detective Story A.B.M Fellow-Sherlockian '' Hello '' I said I took receiver desk 'phone answer call `` Mr. Vantine wish speak sir '' said office-boy `` All right '' I heard snap connection `` Is Lester '' asked Philip Vantine 's voice `` Yes So 're back '' `` Got yesterday Can come house lunch to-day '' `` I 'll glad '' I said meant I liked Philip Vantine `` I 'll look one-thirty '' And happened hour later I walking toward Washington Square Avenue old Vantine mansion stood It almost last survival old régime tide business long since overflowed neighbouring street Avenue swept fashionable folk far uptown Tall office loft building replaced brownstone house old family hold like sullen desperate rear-guard defying advancing enemy Philip Vantine one He born house still lived declared would die He one please matter since unmarried lived alone mitigated increasing roar dust neighbourhood long absence abroad It one returned I may well complete pencil-sketch Vantine fifty year age possessor comfortable fortune something connoisseur art matter collector old furniture little eccentric though I written word I find I must qualify eccentricity persisted spite many temptation remaining bachelor Marriageable woman long since ceased consider mother maturing daughter dismissed significant shake head It got reputation eccentric But reason remaining single way concerned lawyer position firm held many year active work come gradually hand It arduous work consisting part drawing lease collecting rent reinvestment fund adjustment minor difference tenant left discretion But occasionally necessary consult client matter unusual importance get signature paper time I always enjoyed talk followed completion business Vantine good talker knowledge men world gained much travel detached humourous penetrating habit mind He came forward meet I gave man hat stick shook hand heartily I glad see I think glad see He looking excellent health brown voyage `` It 's plain see trip good '' I said `` Yes '' agreed `` I never felt fit But come along talk table There 's little difficulty I want untangle '' I followed upstairs study table laid two placed near low window `` I lunch served '' Vantine explained sat `` really pleasant room left house If I n't plot ground next door place would impossible As I keep sky-scrapers far enough away get little sunshine I 've put air filter double window bedroom keep noise I dare say I manage hang '' `` I understand 'd hate move new house '' I said Vantine made grimace `` I could n't endure new house I 'm used one I find way I know thing I 've grown know man get older value association Besides new house would mean new fitting new furniture `` He paused glanced room Every piece furniture work master `` I suppose found new thing away '' I said `` You always Your luck 's proverbial '' `` Yes 's I wanted talk I brought back six eight piece I 'll show presently They pretty good one thing beauty It 's 's absolutely unique work art Only unfortunately n't mine '' `` It n't '' `` No I n't know whose If I I 'd go buy That 's I want It 's Boule cabinet exquisite I ever saw '' `` Where come '' I questioned surprised `` It came Paris addressed The explanation I think shipper Paris made mistake sent cabinet belonging one else sent mine person '' `` You bought one '' `` Yes n't turned But beside one 's mere daub My man Parks got custom yesterday As Boule cabinet manifest mistake n't discovered whole lot brought uncrated morning '' `` Were n't uncrated custom '' `` No I 've bringing thing good many year custom people know I 'm thief '' `` That 's quite compliment '' I pointed `` They 've tearing thing wide open lately '' `` They 've tip sort I suppose Come '' added answering tap door The door opened Vantine 's man came `` A gentleman see sir '' said handed Vantine card Vantine looked little blankly `` I n't know '' said `` What want '' `` He want see sir bad I say '' `` What '' `` Well I could n't make sir seems important '' `` Could n't make What me ...

# %%
#--------------------------
#Tokenization to integers:

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
#from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = tf.keras.preprocessing.text.Tokenizer(
    num_words=None, #max number of words, only the X most relevant words will be taken
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_``´´{|}~\t\n', #signs that are filtered out
    lower=True, #when true, everything will be converted tp lower case
    split=" ", #word seperator
    char_level=False, #if true, every char will be treated as token
    oov_token=None, #out-of-vocabulary replacement
)

# %%
tokenizer.fit_on_texts(data_content_filtered) #tokenizer gets fit to our texts

# %%
sequences = tokenizer.texts_to_sequences(data_content[0]) 
sequencesFiltered = tokenizer.texts_to_sequences(data_content_filtered[0]) 
#return a list of tokens for the X (see num_words) most common words the tokenizer knows, for every input text
print("unfiltered length: ", len(sequences), " filtered length: ", len(sequencesFiltered))
# Out:
# unfiltered length:  371350  filtered length:  245848

# %%
#from imblearn.under_sampling import RandomUnderSampler

# %%
#Feature Extraction with word2vec using CBOW
#Build vocabulary
from keras.preprocessing import text
from keras.utils import np_utils
from keras.preprocessing import sequence

word2id = tokenizer.word_index

word2id['PAD'] = 0
id2word = {v:k for k, v in word2id.items()}
wids = [[word2id[w] for w in text.text_to_word_sequence(doc)] for doc in data_content_filtered]

vocab_size = len(word2id)
embed_size = 100
window_size = 2

print('Vocabulary Size:', vocab_size)
print('Vocabulary Sample:', list(word2id.items())[:100])
# Out:
# Vocabulary Size: 4958
# Vocabulary Sample: [('i', 1), ("''", 2), ('said', 3), ("'s", 4), ("n't", 5), ('godfrey', 6), ('one', 7), ('he', 8), ('it', 9), ('vantine', 10), ('would', 11), ('cabinet', 12), ('but', 13), ('the', 14), ('man', 15), ('and', 16), ('mr', 17), ('see', 18), ('know', 19), ('grady', 20), ('could', 21), ('hand', 22), ('sir', 23), ('lester', 24), ('back', 25), ('little', 26), ('you', 27), ('room', 28), ('drawer', 29), ("'ll", 30), ('parks', 31), ('simmonds', 32), ('think', 33), ('door', 34), ('yes', 35), ('eye', 36), ('right', 37), ('get', 38), ('m', 39), ('well', 40), ('face', 41), ('way', 42), ('that', 43), ('u', 44), ('there', 45), ('two', 46), ('then', 47), ('time', 48), ('came', 49), ('saw', 50), ('thought', 51), ('got', 52), ('perhaps', 53), ('away', 54), ('armand', 55), ('come', 56), ('thing', 57), ('tell', 58), ('rogers', 59), ('what', 60), ('asked', 61), ('added', 62), ('looked', 63), ('no', 64), ('pigot', 65), ('we', 66), ('like', 67), ('look', 68), ('knew', 69), ("'m", 70), ('told', 71), ('moment', 72), ('day', 73), ('to', 74), ('course', 75), ('say', 76), ('last', 77), ('never', 78), ('went', 79), ('upon', 80), ('house', 81), ('must', 82), ('good', 83), ('turned', 84), ('find', 85), ('woman', 86), ('secret', 87), ('go', 88), ('made', 89), ('story', 90), ('killed', 91), ('nothing', 92), ('night', 93), ('goldberger', 94), ('even', 95), ('opened', 96), ('letter', 97), ('something', 98), ('first', 99), ('want', 100)]

# %%
#Build (context_words, target_word) pair generator
def generate_context_word_pairs(corpus, window_size, vocab_size):
    context_length = window_size*2
    for words in corpus:
        sentence_length = len(words)
        for index, word in enumerate(words):
            context_words = []
            label_word   = []            
            start = index - window_size
            end = index + window_size + 1
            
            context_words.append([words[i] 
                                 for i in range(start, end) 
                                 if 0 <= i < sentence_length 
                                 and i != index])
            label_word.append(word)

            x = sequence.pad_sequences(context_words, maxlen=context_length)
            y = np_utils.to_categorical(label_word, vocab_size)
            yield (x, y)

# %%
i = 0
for x, y in generate_context_word_pairs(corpus=wids, window_size=window_size, vocab_size=vocab_size):
    if 0 not in x[0]:
        print('Context (X):', [id2word[w] for w in x[0]], '-> Target (Y):', id2word[np.argwhere(y[0])[0][0]])
    
        if i == 10:
            break
        i += 1
# Out:
# Context (X): ['a', 'detective', 'a', 'b'] -> Target (Y): story
# Context (X): ['detective', 'story', 'b', 'm'] -> Target (Y): a
# Context (X): ['story', 'a', 'm', 'fellow'] -> Target (Y): b
# Context (X): ['a', 'b', 'fellow', 'sherlockian'] -> Target (Y): m
# Context (X): ['b', 'm', 'sherlockian', "''"] -> Target (Y): fellow
# Context (X): ['m', 'fellow', "''", 'hello'] -> Target (Y): sherlockian
# Context (X): ['fellow', 'sherlockian', 'hello', "''"] -> Target (Y): ''
# Context (X): ['sherlockian', "''", "''", 'i'] -> Target (Y): hello
# Context (X): ["''", 'hello', 'i', 'said'] -> Target (Y): ''
# Context (X): ['hello', "''", 'said', 'i'] -> Target (Y): i
# Context (X): ["''", 'i', 'i', 'took'] -> Target (Y): said

# %%
#Build CBOW Deep Network Model
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Embedding, Lambda

cbow = Sequential()
cbow.add(Embedding(input_dim=vocab_size, output_dim=embed_size, input_length=window_size*2))
cbow.add(Lambda(lambda x: K.mean(x, axis=1), output_shape=(embed_size,)))
cbow.add(Dense(vocab_size, activation='softmax'))

cbow.compile(loss='categorical_crossentropy', optimizer='rmsprop')
print(cbow.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 4, 100)            495800
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4958)              500758
# =================================================================
# Total params: 996,558
# Trainable params: 996,558
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#for simplicity train model for 1 epoch
for epoch in range(1, 2):
    loss = 0.
    i = 0
    for x, y in generate_context_word_pairs(corpus=wids, window_size=window_size, vocab_size=vocab_size):
        i += 1
        loss += cbow.train_on_batch(x, y)
        if i % 100000 == 0:
            print('Processed {} (context, word) pairs'.format(i))

    print('Epoch:', epoch, '\tLoss:', loss)
    print()
# Out:
# Epoch: 1 	Loss: 374939.23200214654

# %%
#Get word embeddings
weights = cbow.get_weights()[0]
weights = weights[1:]
print(weights.shape)

pd.DataFrame(weights, index=list(id2word.values())[1:]).head()
# Out:
# (4957, 100)
#                0         1         2         3         4         5         6   \
# ''       0.045854 -0.165436 -0.207914  0.326770  0.001337  0.147286  0.500185
# said     0.266274  0.060354 -0.050025  0.173057  0.024486  0.088786 -0.126871
# 's       0.039222 -0.081422 -0.083696 -0.389515  0.083708 -0.398028 -0.004899
# n't     -0.135193  0.182729 -0.269230  0.071273 -0.175044  0.200636 -0.056523
# godfrey  0.245025 -0.136464 -0.159645  0.041218 -0.114887 -0.067640 -0.081453
#
#                7         8         9   ...        90        91        92  \
# ''      -0.093851 -0.337858 -0.346954  ... -0.042295  0.534500 -0.045093
# said    -0.169511  0.055480  0.218774  ... -0.115254  0.358291  0.208316
# 's       0.001924  0.110763  0.080004  ... -0.058775  0.063120  0.254512
# n't     -0.184438  0.245725 -0.054974  ... -0.114687  0.009465  0.251469
# godfrey -0.177018  0.203750 -0.065737  ...  0.047499  0.114484  0.316027
#
#                93        94        95        96        97        98        99
# ''       0.057744 -0.032164 -0.512889 -0.273319 -0.406446 -0.466524 -0.027504
# said    -0.460192  0.598387 -0.325481  0.031821 -0.099580  0.179423 -0.122406
# 's      -0.150308 -0.208595  0.037217  0.186677  0.433093 -0.146582 -0.043241
# n't     -0.259385  0.002071 -0.146957  0.209228  0.250680  0.050126  0.060977
# godfrey -0.030068 -0.440598 -0.080517  0.023155  0.084812  0.189880  0.146938
#
# [5 rows x 100 columns]

# %%
#Build a distance matrix to view the most similar words (contextually)
from sklearn.metrics.pairwise import euclidean_distances

# compute pairwise distance matrix
distance_matrix = euclidean_distances(weights)
print(distance_matrix.shape)

# view contextually similar words
similar_words = {search_term: [id2word[idx] for idx in distance_matrix[word2id[search_term]-1].argsort()[1:6]+1] 
                   for search_term in ['house', 'letter', 'eye']}

similar_words
# Out:
# (4957, 4957)
# {'house': ['part', 'nature', 'minute', 'kind', 'why'],
#  'letter': ['packet', 'present', 'montespan', 'mechanism', 'yet'],
#  'eye': ['head', 'staring', 'face', 'forward', 'moment']}
